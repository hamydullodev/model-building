# %%
y_actual=[3,5,6,7,8]
y_pred=[3,4,5,7,8]

# %%
from sklearn.metrics import r2_score,mean_absolute_error,root_mean_squared_error

# %%
r2=r2_score(y_pred,y_actual)
mse=mean_absolute_error(y_pred,y_actual)
rmse=root_mean_squared_error(y_pred,y_actual)
mae=mean_absolute_error(y_pred,y_actual)

# %%
print(r2)
print(mse)
print(rmse)
print(mae)
# Out:
# 0.8837209302325582
# 0.4
# 0.6324555320336759
# 0.4

# %%
import pandas as pd
df=pd.read_csv("IMDB_Movies_Dataset (2).csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                       Title  Average Rating  \
# 0           0                    The Shawshank Redemption             9.3
# 1           1  Attack on Titan the Movie: The Last Attack             9.3
# 2           2                               The Godfather             9.2
# 3           3                              Hababam Sinifi             9.2
# 4           4         Ramayana: The Legend of Prince Rama             9.2
#
#                              Director  \
# 0                      Frank Darabont
# 1                    Yûichirô Hayashi
# 2                Francis Ford Coppola
# 3                       Ertem Egilmez
# 4  Ram Mohan, Yûgô Sakô, Koichi Saski
#
#                                           Writer  Metascore  \
# 0                   Stephen King, Frank Darabont       82.0
# 1  Natsuki Hanae, Yoshimasa Hosoya, Marina Inoue        NaN
# 2               Mario Puzo, Francis Ford Coppola      100.0
# ...

# %%
def clean(df):
    for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype=='object':
                df[col].fillna(df[col].mode()[0],inplace=True)
            else:
                df[col].fillna(df[col].mean(),inplace=True)
    return df

# %%
clean(df)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9368\1924034062.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0],inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_9368\1924034062.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

def encodla(df):
    encoder = LabelEncoder()

    for col in df.columns.to_list(): 
        if df[col].dtype == 'object':
            if df[col].nunique() <= 6:
                dummies = pd.get_dummies(df[col], prefix=col, dtype=int)
                df.drop(columns=[col], inplace=True)
                df[dummies.columns] = dummies
            else:
                df[col] = encoder.fit_transform(df[col].astype(str))
    
    return df

# %%
df=encodla

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler

# %%
def scale(df):
    for col in df.columns:
        if [col].dtype=='object':
            df[col]=scaler.fit_transform(df[col])
    return df

# %%
scale(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 scale(df)
#
# Cell In[88], line 2, in scale(df)
#       1 def scale(df):
# ----> 2     for col in df.columns:
#       3         if [col].dtype=='object':
#       4             df[col]=scaler.fit_transform(df[col])
#
# AttributeError: 'function' object has no attribute 'columns'

# %%
x=df.drop('Runtime',axis=1)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Title                   0
# Average Rating          0
# Director                0
# Writer                  1
# Metascore            1934
# Cast                    7
# Release Date            0
# Country of Origin       3
# Languages              21
# Budget               2338
# Worldwide Gross      1094
# Runtime                 0
# dtype: int64

# %%
clean(df)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9368\1924034062.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0],inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_9368\1924034062.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
encodla(df)
# Out:
#       Unnamed: 0  Title  Average Rating  Director  Writer   Metascore  Cast  \
# 0              0   4288             9.3       711    3851   82.000000  4504
# 1              1    373             9.3      2620    2884   74.684452  3367
# 2              2   3939             9.2       703    2592  100.000000  3002
# 3              3   1504             9.2       661    4123   74.684452  3312
# 4              4   3083             9.2      1962    3286   74.684452   396
# ...          ...    ...             ...       ...     ...         ...   ...
# 4984         495   2092             7.2      2635    2107   74.684452   719
# 4985         496   3988             7.2      2111    3508   74.684452   478
# 4986         497   2037             7.2      2356    1583   74.684452  4190
# 4987         498   2089             7.2      2112    3512   74.684452  3826
# 4988         499    790             7.2      1358    2330   74.684452  4921
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Title                0
# Average Rating       0
# Director             0
# Writer               0
# Metascore            0
# Cast                 0
# Release Date         0
# Country of Origin    0
# Languages            0
# Budget               0
# Worldwide Gross      0
# Runtime              0
# dtype: int64

# %%
x=df.drop('Worlwide Gross',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 x=df.drop('Worlwide Gross',axis=1)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
# ...

# %%
y=['Worldwide Gross']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression

# %%
lr
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 lr.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
y_pred=lr.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 y_pred=lr.predict(x_test)
#
# NameError: name 'x_test' is not defined
